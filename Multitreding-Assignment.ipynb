# %%
# Q1. What is multithreading in python? Why is it used? Name the module used to handle threads in python.
# Answer :-
# In computing, a process is an instance of a computer program that is being executed. Any process has 3 basic components:

# An executable program.
# The associated data needed by the program (variables, workspace, buffers, etc.)
# The execution context of the program (State of the process)

# Threading Modules. The threading module is a high-level implementation of multithreading used to deploy an application in Python. To use multithreading, we need to import the threading module in Python Program.

# %%
# Q2. Why threading module used? Write the use of the following functions
# 1.activeCount()
# 2.currentThread()
# 3.enumerate()
# Answer :-
# The Threading Module is a standard Python library that provides multithreading support for your application, which
#     The thread is a lightweight process that shares resources with other threads in an application, and it can be
# The Threading Module is a standard Python library that allows you to create multiple threads in your program,
# and manage them all from one place. The main thread (the first created) will be called Main
# Thread and it’s ID number would always remain as 0. All other threads are assigned an
# integer value starting with 1 which increases by 1 for each new thread started after this initial thread.


# 1.activeCount()
# : This function returns how many active threads there currently exist on our system at any given time.
# It does not include terminated or daemonic threads!


 # 2.currentThread()
# It gives us information about current running thread object itself like its name , id etc .


# 3.enumerate()
# : enumerate(iterable[, start=0]) -> list of tuples
# Return an iterator over elements of iterable, starting with index start (default 0).
# Each tuple consists of two items: index i and element e[i].

# %%
# Q3. Explain the following functions
#  run()
#  start()
#  join()
#  isAlive()
# Amswer :-
#  1)run(): This function starts a thread and returns its identifier (thread object).
# The newly created thread will execute in parallel with other threads of same process, but not necessarily at the
# The new thread will execute in parallel with other threads of same process, but not necessarily at the same
# time as them. The return value from this call can be used to identify which thread has finished execution
# by calling
# join(). If no timeout argument is given or if it’s None then wait forever
# for completion; otherwise raise an exception after that many seconds have elapsed without success.
    
# 2)start
# This method just marks the beginning of executing code for a particular Thread instance. It does nothing else
# This method causes the Python interpreter to begin executing the current code block within the newly created thread.
# This method must always be called by the main program before any calls are made on the returned Thread
# instance. It does nothing else than creating a separate stack for executing the code specified by target parameter.
# instance. It does nothing else than setting up the internal flag needed for running the target function when the
# instance. It does nothing else than create a separate stack for executing Python code within the current process.
# instance. It does nothing else except mark the thread object as alive. Calling start more than once on
# a single thread instance results in undefined behavior.

# 3)Join: When you want your code
# to continue only when all child processes finish their work ,you should use
# the join()method .
# It blocks until another thread terminates—either normally or due to an uncaught exception being raised within
# the target —and returns either None(if successful),or raises a RuntimeErrorexception if there was some
# error during termination.

# 4)isAlive : Returns True while the current thread is running, False
# if it has exited or been stopped using stop_thread().

# %%
# Q4.  Write a python program to create two threads. Thread one must print the list of squares and thread 
# two must print the list of cubes.
# Answer :-
import threading

def print_squares():
    for i in range(1, 11):
        print(f"Square of {i}: {i*i}")

def print_cubes():
    for i in range(1, 11):
        print(f"Cube of {i}: {i*i*i}")

# Create the first thread for printing squares
thread1 = threading.Thread(target=print_squares)

# Create the second thread for printing cubes
thread2 = threading.Thread(target=print_cubes)

# Start both threads
thread1.start()
thread2.start()

# Wait for both threads to finish
thread1.join()
thread2.join()

print("Done!")
# Out:
# Square of 1: 1
# Square of 2: 4
# Square of 3: 9
# Square of 4: 16
# Square of 5: 25
# Square of 6: 36
# Square of 7: 49
# Square of 8: 64
# Square of 9: 81
# Square of 10: 100
# Cube of 1: 1
# Cube of 2: 8
# Cube of 3: 27
# Cube of 4: 64
# Cube of 5: 125
# Cube of 6: 216
# Cube of 7: 343
# Cube of 8: 512
# Cube of 9: 729
# Cube of 10: 1000
# Done!

# %%
# Q5. State advantages and disadvantages of multithreading.
# Answer :-
# Advantage: 
# 1) It can improve the performance by using multiple processors to execute a program simultaneously, which is
# called parallel processing or multiprocessing.

# 2) Multitasking allows more than one task at once
# on single processor system (i.e., it increases throughput). 

# 3) The execution time for
# each thread will be less as compared with sequential code because threads share resources like memory space etc..

# Disadvantages:
# It is difficult to write a program that uses multiple threads correctly, because the programmer must be
# aware of all possible interactions between different parts of his/her code running in separate threads.

# If any thread crashes then whole application will crash as well.

# %%
# Q6. Explain deadlocks and race conditions.
# Answer :-
# Deadlock is a situation where two or more processes are waiting for each other to release some resource,
#     but they can't because the resources have been locked by another process already in use. This results into
# but they both can't proceed until the first one releases it's resources. In this case all of
# them will be blocked forever in that state. 
# Race condition occurs when multiple threads try to access
# same data at once which results into unpredictable behavior.
